# %% [markdown]
# # **Project Name**    - Yes Bank Price Analysis

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Poonam Thakur
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing and predicting the stock closing price of Yes Bank using Machine Learning techniques. The dataset contains historical stock market data, including the Date, Open, High, Low, and Close prices. The main objective of this project is to understand the trends in stock prices and build a regression model that can accurately predict the closing price based on the available features.
# The project begins with data preprocessing, where the dataset is loaded and checked for missing values, duplicate records, and data types. The Date column is converted into the appropriate format to make it suitable for analysis. Exploratory Data Analysis (EDA) is then performed to understand the distribution of the data and the relationships between different features. Various visualizations such as line charts, histograms, and correlation heatmaps are used to identify trends and patterns in the stock prices.
# After preprocessing and analysis, the dataset is divided into training and testing sets. A Linear Regression model is trained using the Open, High, and Low prices as input features, while the Close price is used as the target variable. The model learns the relationship between these variables and predicts the closing price of the stock.
# The performance of the model is evaluated using standard regression metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R² Score. These metrics help determine how accurately the model predicts stock prices. The predicted values are also compared with the actual values using graphical visualizations.
# This project demonstrates the complete machine learning workflow, including data preprocessing, exploratory data analysis, model training, prediction, and performance evaluation. It provides practical experience in applying regression techniques to financial data and helps in understanding how historical stock market information can be used to make predictions. Overall, the project highlights the importance of data analysis and machine learning in solving real-world business and financial problems.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The stock market is highly volatile, making it difficult for investors to predict future stock prices accurately. This project aims to analyze the historical stock price data of Yes Bank and build a Machine Learning regression model to predict the closing stock price based on features such as Open, High, and Low prices. The objective is to improve prediction accuracy and support better investment decisions.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to develop a machine learning model that can accurately predict the closing stock price of Yes Bank using historical stock market data. The model aims to help investors, financial analysts, and businesses understand stock price trends, reduce investment risk, and support better financial decision-making. By analyzing historical data, the project provides valuable insights that can assist in making informed investment strategies.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib . pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv("data_YesBank_StockPrices.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (185, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    str
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), str(1)
# memory usage: 8.4 KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values
df.isnull().sum().plot(kind='bar')
plt.title("Missing Values")
plt.xlabel("columns")
plt.ylabel("Count of Missing Value")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains historical stock price data of Yes Bank with five columns: Date, Open, High, Low, and Close. It includes numerical features related to stock prices and one date column representing the trading period. The dataset has no missing values and no duplicate records, making it clean and suitable for analysis. It can be used for Exploratory Data Analysis (EDA) and for building a Machine Learning Regression model to predict the closing stock price

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='str')

# %%
# Dataset Describe
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Date: Represents the trading date of the stock.

# %% [markdown]
# Open: Opening price of the stock on a trading day.

# %% [markdown]
# High: Highest price of the stock during the trading day.

# %% [markdown]
# Low: Lowest price of the stock during the trading day.

# %% [markdown]
# Close: Closing price of the stock. This is the target variable used for prediction.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = df.nunique()

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
unique_values.plot(kind='bar')

plt.title("Unique Values in Each Variable")
plt.xlabel("Variables")
plt.ylabel("Number of Unique Values")
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of dataset
df1 = df.copy()

# Check missing values
print(df1.isnull().sum())

# Remove duplicate rows
df1.drop_duplicates(inplace=True)

# Convert Date column to datetime format
df1['Date'] = pd.to_datetime(df1['Date'])

# Check data types
print(df1.dtypes)

# Sort data by Date
df1.sort_values(by='Date', inplace=True)

# Reset index
df1.reset_index(drop=True, inplace=True)

# Final dataset information
print(df1.info())
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64
# Date     datetime64[us]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object
# <class 'pandas.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    datetime64[us]
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: datetime64[us](1), float64(4)
# memory usage: 7.4 KB
# None
# C:\Users\POONAMTHAKURHP\AppData\Local\Temp\ipykernel_31468\3430535305.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Date'] = pd.to_datetime(df1['Date'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Created a copy of the original dataset.

# %% [markdown]
# Checked for missing values and found no missing data.

# %% [markdown]
# Removed duplicate records

# %% [markdown]
# Converted the Date column into datetime format.

# %% [markdown]
# Sorted the dataset by date for proper time-series analysis

# %% [markdown]
# Reset the index after preprocessing.

# %% [markdown]
# Verified the data types and dataset structure.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Closing Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is used because the data is time-based. It helps to visualize how the closing stock price changes over time and identifies trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the Open and Close prices are very close on most trading days. However, some days show noticeable differences, indicating higher market volatility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. These insights help investors and analysts understand daily price movements, identify market trends, and make better investment decisions. Large differences between Open and Close prices may indicate high volatility and potential trading opportunities.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.figure(figsize=(10,5))

df[['Open', 'Close']].head(20).plot(kind='bar')

plt.title("Open vs Close Stock Price")
plt.xlabel("Trading Days")
plt.ylabel("Stock Price")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to comapre the open and close prices for different trading days

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Open and Close prices are close on most trading days , while some days show noticeable differences,indicating marketing fluctuations

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# These insight help investor to understand daily price movements and make better investment decision.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

plt.figure(figsize=(6,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a correlation heatmap because it helps identify the relationship between numerical variables. It is useful for understanding which features are strongly correlated with each other

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Open, High, Low, and Close price columns show a strong positive correlation. This indicates that these stock price variables move together over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Understanding the correlation between stock price variables helps in feature selection, stock trend analysis, and building more accurate prediction models for investment and financial decision-making.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'], color='blue')

plt.title("Yes Bank Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a line chart because it is the best way to visualize stock price trends over time. It clearly shows how the closing price changes from one date to another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the overall movement of Yes Bank's closing stock price over time. It helps identify periods of growth, decline, and fluctuations in the stock market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Analyzing stock price trends helps investors and analysts make informed investment decisions, identify market patterns, and improve future price prediction models.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

plt.figure(figsize=(6,5))

sns.heatmap(
    df[['Open', 'High', 'Low', 'Close']].corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title("Correlation Heatmap of Stock Prices")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the correlation heatmap to understand the relationship between the numerical variables (Open, High, Low, and Close). It clearly shows the strength and direction of correlation among stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Open, High, Low, and Close prices are highly positively correlated. This indicates that these stock price variables move together and have a strong linear relationship

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Understanding the strong correlation between stock price variables helps in forecasting stock prices, identifying trends, and building more accurate predictive models for investment and financial analysis.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

plt.figure(figsize=(8,6))

df[['Open', 'High', 'Low', 'Close']].plot(kind='box')

plt.title("Box Plot of Stock Prices")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a box plot to identify the distribution of stock prices and detect any outliers in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows the spread of Open, High, Low, and Close prices. It also highlights any outliers and helps understand the variability in stock prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Detecting outliers and understanding price variability helps improve data quality and build more accurate stock price prediction models.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

plt.figure(figsize=(8,5))

plt.hist(df['Close'], bins=20)

plt.title("Distribution of Closing Stock Price")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a histogram because it helps visualize the distribution of closing stock prices and shows how frequently different price ranges occur.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows the frequency distribution of the closing prices. It helps identify the most common price ranges and whether the data is skewed or evenly distributed.The histogram shows the frequency distribution of the closing prices. It helps identify the most common price ranges and whether the data is skewed or evenly distributed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Understanding the distribution of stock prices helps analysts identify market behavior, detect unusual price patterns, and build more reliable prediction models.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

plt.figure(figsize=(8,6))

plt.scatter(df['Open'], df['Close'])

plt.title("Open Price vs Close Price")
plt.xlabel("Open Price")
plt.ylabel("Close Price")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a scatter plot to analyze the relationship between the Open and Close stock prices. It helps identify whether the two variables have a positive correlation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows that Open and Close prices have a strong positive relationship. As the opening price increases, the closing price also tends to increase.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes. Understanding the relationship between Open and Close prices helps in stock price analysis, trend identification, and building more accurate machine learning models for price prediction.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

plt.figure(figsize=(10,5))

plt.plot(df['Date'], df['Open'], label='Open')
plt.plot(df['Date'], df['Close'], label='Close')

plt.title("Open vs Close Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a line chart because it clearly shows the trend of Open and Close stock prices over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Open and Close prices follow a similar trend over time, indicating consistent stock price movement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps identify stock price trends and supports better investment and business decisions.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

df['20_Day_MA'] = df['Close'].rolling(window=20).mean()

plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['20_Day_MA'], label='20-Day Moving Average')

plt.title("Close Price vs 20-Day Moving Average")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this chart to compare the actual closing price with its 20-day moving average. It helps identify the overall trend by smoothing daily price fluctuations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The moving average highlights the long-term trend of the stock. When the closing price stays above the moving average, it indicates an upward trend, while prices below it may indicate a downward trend.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact. The moving average helps identify long-term trends and supports better investment decisions. A sustained downward trend may indicate negative growth, allowing investors to reduce risk and avoid potential losses.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Chart - 11 visualization code

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a heatmap because it clearly shows the correlation between numerical variables. It helps identify strong positive and negative relationships in the stock price data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows that Open, High, Low, and Close prices are highly positively correlated. This indicates that these variables move together and are strong indicators of stock price behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding correlations helps investors and analysts build better prediction models and make informed investment decisions. Strong correlations improve forecasting, while weak correlations indicate variables that contribute less to price prediction.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

plt.figure(figsize=(8,5))
plt.hist(df['Close'], bins=20, edgecolor='black')
plt.title('Distribution of Closing Prices')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This histogram is used to understand the distribution of the stock's closing prices. It helps identify the most common price range, spread, and any unusual values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how frequently different closing prices occur. It helps identify the most common price range and whether the data is evenly distributed or skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding the distribution of closing prices helps investors assess stock price behavior, identify volatility, and make better investment and risk management decisions. If the distribution is highly skewed or volatile, it may indicate higher investment risk.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

plt.figure(figsize=(8,5))
plt.boxplot(df['Close'])
plt.title('Box Plot of Closing Prices')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is used to identify the distribution of closing prices and detect any outliers in the stock data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the median, spread, and possible outliers in the closing prices. Any points outside the whiskers represent unusual stock price values.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Identifying outliers helps investors detect abnormal market movements, manage risk, and make more informed investment decisions. It also improves the reliability of further data analysis.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(8,6))
sns.heatmap(df[['Open', 'High', 'Low', 'Close']].corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap of Stock Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used to visualize the relationship between numerical variables. It helps identify strongly and weakly correlated stock price features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows that Open, High, Low, and Close prices are highly positively correlated. This means these variables tend to move together over time.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(df[['Open', 'High', 'Low', 'Close']])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair Plot is used to visualize the relationship between multiple numerical variables simultaneously. It helps identify correlations, trends, and the distribution of each variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Pair Plot shows that Open, High, Low, and Close prices have a strong positive relationship. The diagonal plots indicate the distribution of each variable, while the scatter plots show that these stock price variables move together.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis, the client should monitor stock price trends using historical data, moving averages, and price correlations. Regular analysis of Open, High, Low, and Close prices can help identify market trends, reduce investment risk, and support better decision-making. Using predictive models in the future can further improve stock price forecasting and investment strategies.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis (EDA) of the Yes Bank stock price dataset revealed important insights into stock price behavior. The analysis showed strong positive correlations among Open, High, Low, and Close prices, while visualizations helped identify trends, distributions, and possible outliers. Overall, the findings can support investors and financial analysts in making informed decisions and can serve as a foundation for future stock price prediction models.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
